# %% [markdown]
# <a href="https://colab.research.google.com/github/ericmuga253/Python-Data-/blob/main/Exercises_(7).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
wine=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data')
wine.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
wine.shape
# Out:
# (177, 14)

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
deletion=[0,3,6,8,10,12,13]
wine.drop(wine.columns[deletion], axis=1, inplace=True)
wine.head()
# Out:
#    14.23  1.71  15.6  127  3.06  2.29  1.04
# 0  13.20  1.78  11.2  100  2.76  1.28  1.05
# 1  13.16  2.36  18.6  101  3.24  2.81  1.03
# 2  14.37  1.95  16.8  113  3.49  2.18  0.86
# 3  13.24  2.59  21.0  118  2.69  1.82  1.04
# 4  14.20  1.76  15.2  112  3.39  1.97  1.05

# %%
wine.shape
# Out:
# (177, 7)

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
columns=['alcohol','malic_acid','alcalinity_of_ash','magnesium','flavanoids','proanthocyanins',' hue']
wine.columns=columns
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    13.20        1.78               11.2        100        2.76
# 1    13.16        2.36               18.6        101        3.24
# 2    14.37        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
import numpy as np
wine.iloc[:3,:]=np.nan

# %%
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN         NaN                NaN        NaN         NaN
# 1      NaN         NaN                NaN        NaN         NaN
# 2      NaN         NaN                NaN        NaN         NaN
# 3    13.24        2.59               21.0      118.0        2.69
# 4    14.20        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0              NaN   NaN
# 1              NaN   NaN
# 2              NaN   NaN
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.loc[3:5,'magnesium']=np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN         NaN                NaN        NaN         NaN
# 1      NaN         NaN                NaN        NaN         NaN
# 2      NaN         NaN                NaN        NaN         NaN
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2        NaN        3.39
#
#    proanthocyanins   hue
# 0              NaN   NaN
# 1              NaN   NaN
# 2              NaN   NaN
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine.loc[:4,'alcohol'].fillna(10, inplace=True)
wine.loc[:,'magnesium'].fillna(100, inplace=True)
wine.head(10)
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00         NaN                NaN      100.0         NaN
# 1    10.00         NaN                NaN      100.0         NaN
# 2    10.00         NaN                NaN      100.0         NaN
# 3    13.24        2.59               21.0      100.0        2.69
# 4    14.20        1.76               15.2      100.0        3.39
# 5    14.39        1.87               14.6      100.0        2.52
# 6    14.06        2.15               17.6      121.0        2.51
# 7    14.83        1.64               14.0       97.0        2.98
# 8    13.86        1.35               16.0       98.0        3.15
# 9    14.10        2.16               18.0      105.0        3.32
#
#    proanthocyanins   hue
# 0              NaN   NaN
# 1              NaN   NaN
# 2              NaN   NaN
# 3             1.82  1.04
# 4             1.97  1.05
# 5             1.98  1.02
# 6             1.25  1.06
# 7             1.98  1.08
# ...

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
wine.isnull().sum()
# Out:
# alcohol              0
# malic_acid           3
# alcalinity_of_ash    3
# magnesium            0
# flavanoids           3
# proanthocyanins      3
#  hue                 3
# dtype: int64

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
import numpy as np
array=np.random.randint(0,10,size=10)
print(array)
# Out:
# [5 0 8 8 2 0 8 1 0 4]

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
np.random.seed(0)
array=np.random.randint(0,10,size=10)
df=pd.DataFrame(index=array, columns=range(1), data=np.nan)
print(df)
# Out:
#     0
# 5 NaN
# 0 NaN
# 3 NaN
# 3 NaN
# 7 NaN
# 9 NaN
# 3 NaN
# 5 NaN
# 2 NaN
# 4 NaN

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
df.isnull().sum()
# Out:
# 0    10
# dtype: int64

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
wine.alcohol.notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 172    True
# 173    True
# 174    True
# 175    True
# 176    True
# Name: alcohol, Length: 177, dtype: bool

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
df.sort_index()
# Out:
#     0
# 0 NaN
# 2 NaN
# 3 NaN
# 3 NaN
# 3 NaN
# 4 NaN
# 5 NaN
# 5 NaN
# 7 NaN
# 9 NaN

# %% [markdown]
# ### BONUS: Create your own question and answer it.
